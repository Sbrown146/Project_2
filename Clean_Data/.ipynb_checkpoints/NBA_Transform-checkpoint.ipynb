# %%
import pandas as pd
import numpy as np
import csv

# %%
nhl_df = pd.read_csv("Clean_NHL.csv")

# %%
nhl_df
# Out:
#        Unnamed: 0  season                 Home  G.1              Visitor    G  \
# 0           39233    2007  Carolina Hurricanes  2.0       Buffalo Sabres  3.0
# 1           39234    2007   Colorado Avalanche  2.0         Dallas Stars  3.0
# 2           39235    2007  Toronto Maple Leafs  1.0      Ottawa Senators  4.0
# 3           39236    2007    Atlanta Thrashers  2.0  Tampa Bay Lightning  3.0
# 4           39237    2007    Detroit Red Wings  1.0    Vancouver Canucks  3.0
# ...           ...     ...                  ...  ...                  ...  ...
# 11344       50577    2015  Tampa Bay Lightning  4.0   Chicago Blackhawks  3.0
# 11345       50578    2015   Chicago Blackhawks  2.0  Tampa Bay Lightning  3.0
# 11346       50579    2015   Chicago Blackhawks  2.0  Tampa Bay Lightning  1.0
# 11347       50580    2015  Tampa Bay Lightning  1.0   Chicago Blackhawks  2.0
# 11348       50581    2015   Chicago Blackhawks  2.0  Tampa Bay Lightning  0.0
#
#        playoffs
# ...

# %%
total_games=nhl_df["Home"].value_counts()
total_

# %%
nhl_df
# Out:
#        season                 Home  G.1              Visitor    G  playoffs
# 0        2007  Carolina Hurricanes  2.0       Buffalo Sabres  3.0         0
# 1        2007   Colorado Avalanche  2.0         Dallas Stars  3.0         0
# 2        2007  Toronto Maple Leafs  1.0      Ottawa Senators  4.0         0
# 3        2007    Atlanta Thrashers  2.0  Tampa Bay Lightning  3.0         0
# 4        2007    Detroit Red Wings  1.0    Vancouver Canucks  3.0         0
# ...       ...                  ...  ...                  ...  ...       ...
# 11344    2015  Tampa Bay Lightning  4.0   Chicago Blackhawks  3.0         1
# 11345    2015   Chicago Blackhawks  2.0  Tampa Bay Lightning  3.0         1
# 11346    2015   Chicago Blackhawks  2.0  Tampa Bay Lightning  1.0         1
# 11347    2015  Tampa Bay Lightning  1.0   Chicago Blackhawks  2.0         1
# 11348    2015   Chicago Blackhawks  2.0  Tampa Bay Lightning  0.0         1
#
# [11349 rows x 6 columns]

# %%
nhl_df.loc[nhl_df["season"]<2008]
# Out:
#       season                 Home  G.1              Visitor    G  playoffs
# 0       2007  Carolina Hurricanes  2.0       Buffalo Sabres  3.0         0
# 1       2007   Colorado Avalanche  2.0         Dallas Stars  3.0         0
# 2       2007  Toronto Maple Leafs  1.0      Ottawa Senators  4.0         0
# 3       2007    Atlanta Thrashers  2.0  Tampa Bay Lightning  3.0         0
# 4       2007    Detroit Red Wings  1.0    Vancouver Canucks  3.0         0
# ...      ...                  ...  ...                  ...  ...       ...
# 1306    2007        Anaheim Ducks  3.0      Ottawa Senators  2.0         1
# 1307    2007        Anaheim Ducks  1.0      Ottawa Senators  0.0         1
# 1308    2007      Ottawa Senators  5.0        Anaheim Ducks  3.0         1
# 1309    2007      Ottawa Senators  2.0        Anaheim Ducks  3.0         1
# 1310    2007        Anaheim Ducks  6.0      Ottawa Senators  2.0         1
#
# [1311 rows x 6 columns]
